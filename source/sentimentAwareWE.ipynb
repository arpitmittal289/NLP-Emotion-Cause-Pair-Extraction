# %% [markdown]
# ## Sentiment Aware Word Embeddings

# %% [markdown]
# #### The goal of this module is to create sentiment aware word embeddings for a corpus using Word2Vec and an existing Emotional Lexicon.
# ### References:
# #### https://www.mdpi.com/2076-3417/9/7/1334
# #### http://saifmohammad.com/WebPages/lexicons.html

# %%
import json
import pandas as pd
import numpy as np
import nltk
from gensim import models
import contractions

import warnings
warnings.filterwarnings('ignore')

from bs4 import BeautifulSoup, Tag

# %% [markdown]
# ### Getting the Dataset

# %%
import pickle

with open('../outputs/reviews_for_embeddings.pkl', 'rb') as file:
  rv = pickle.load(file)
df = pd.DataFrame(rv,columns=["reviewText"])
df
# Out:
#                                              reviewText
# 0     We got this GPS for my husband who is an (OTR)...
# 1     I'm a professional OTR truck driver, and I bou...
# 2     Well, what can I say.  I've had this unit in m...
# 3     Not going to write a long review, even thought...
# 4     I've had mine for a year and here's what we go...
# ...                                                 ...
# 9995  The audio connector was very difficult to make...
# 9996  This is a solid well built unit that I have no...
# 9997  Plantronics T20: 90% PERFECT, 10% DEADLYThis w...
# 9998  Here's what's wrong with it:* People are const...
# 9999  I've used Plantronics headsets for years.  I w...
#
# [10000 rows x 1 columns]

# %% [markdown]
# ### Getting the Emotion Lexicon

# %%
edf = None
with open("../resources/NRC-Emotion-Intensity-Lexicon-v1/NRC-Emotion-Intensity-Lexicon-v1.txt", "r") as efile:
    edf = pd.read_csv(efile, sep="\t")
edf
# Out:
#            word emotion  emotion-intensity-score
# 0      outraged   anger                    0.964
# 1     brutality   anger                    0.959
# 2        hatred   anger                    0.953
# 3       hateful   anger                    0.940
# 4     terrorize   anger                    0.939
# ...         ...     ...                      ...
# 9894   fugitive   trust                    0.141
# 9895    divorce   trust                    0.133
# 9896   mistakes   trust                    0.133
# 9897       bait   trust                    0.133
# 9898  scoundrel   trust                    0.117
#
# [9899 rows x 3 columns]

# %% [markdown]
# ### Word Embeddings from Dataset

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
from itertools import chain
from collections import Counter

# reviews = df["summary"] + df["reviewText"] 
reviews = df["reviewText"]
sentences = list(chain(*reviews.apply(sent_tokenize)))
sentences = [list(map(str.lower, word_tokenize(s))) for s in sentences]

# %%
wv_model = models.Word2Vec(sentences=sentences, vector_size=300, window=11, min_count=1)

# %%
vocab = wv_model.wv.index_to_key
word_embeddings = {}
for word in vocab:
    word_embeddings[word] = wv_model.wv[word]

# %%
### Saving W2V model in an external file.
with open("../output/wordEmbeddings.pkl", "wb") as wvfile:
    pickle.dump(word_embeddings, file=wvfile)

# %%
### Demonstrating loading the word vectors back into memory.
with open("../output/wordEmbeddings.pkl", "rb") as wvfile:
    wv = pickle.load(wvfile)
wv["joy"]
# Out:
# array([ 0.02745958,  0.08550036,  0.07900085,  0.04433017,  0.02539896,
#        -0.11310062, -0.01601092,  0.16247016, -0.00768178,  0.01936728,
#         0.06455947, -0.08121633,  0.04351631, -0.00928702, -0.18439871,
#        -0.12359925,  0.06831494, -0.04288586,  0.05628758,  0.07154419,
#        -0.02353128,  0.04543516, -0.04048407, -0.03799186, -0.01870383,
#        -0.04591846, -0.13031225,  0.01073328,  0.00336856, -0.10409253,
#         0.02436649, -0.07125816,  0.12994334, -0.03170492,  0.03955619,
#         0.03479991,  0.04915466, -0.00865234, -0.08672893, -0.00970373,
#         0.04662003,  0.05660615, -0.05405471, -0.00351273, -0.02046751,
#         0.0462717 ,  0.09312263,  0.00190855, -0.08558293, -0.00421814,
#        -0.01625445, -0.00563715, -0.02278447,  0.02177822, -0.01663387,
#         0.04934742, -0.01682947, -0.0608725 , -0.01517394, -0.00665053,
#        -0.00611602, -0.0088266 , -0.0092489 ,  0.07563432, -0.02942354,
#         0.00035669,  0.00117109,  0.08894952,  0.00667536, -0.00281323,
#        -0.03661084,  0.03825344,  0.0435179 , -0.04745309, -0.04200664,
#         0.01976494, -0.06871419, -0.01519384, -0.06248244,  0.08138881,
#        -0.03738529, -0.02963651, -0.00391246,  0.2311125 , -0.01685535,
#         0.04713373,  0.00420045, -0.051405  ,  0.05751228,  0.02742278,
#         0.03009238, -0.06477927,  0.06773444,  0.07038731, -0.0040666 ,
#         0.04612112, -0.03357112,  0.0544107 , -0.1162769 ,  0.03892195,
#        -0.01385988, -0.03747277,  0.01132327,  0.02603544,  0.01530454,
#        -0.04399266,  0.00824508, -0.05986907,  0.0040777 ,  0.08047114,
#        -0.06926709, -0.09833517,  0.03294726,  0.06234433,  0.02167371,
#         0.08652414, -0.12086774, -0.07481016,  0.03436112, -0.0835653 ,
#         0.06845918,  0.11109704,  0.11170539, -0.03146627,  0.01372288,
#         0.11539713,  0.01798089,  0.05946046, -0.03361335,  0.03984535,
#         0.00540844,  0.12258762,  0.0511184 , -0.12523597,  0.03289679,
#         0.00887721, -0.10032856, -0.10516709, -0.08328085, -0.07714764,
#         0.00586488, -0.05846668, -0.01617786,  0.03491687, -0.00701693,
#        -0.03527753, -0.06262796, -0.06546012,  0.03688941,  0.00134617,
#        -0.01078656, -0.11850357, -0.03581218, -0.00501996,  0.04974158,
#         0.03343732, -0.06096041, -0.10289322, -0.07208583,  0.07522603,
#         0.03723191, -0.03267255, -0.08266226,  0.07947922,  0.03110507,
#         0.00389818, -0.04272077,  0.01490289,  0.11861323,  0.00981613,
#        -0.03941644, -0.00708181,  0.00816024,  0.07872198, -0.03074789,
#         0.0557321 , -0.01132663, -0.17843775,  0.05913476, -0.00629533,
#         0.0585877 ,  0.04036779, -0.04175845, -0.02392782, -0.06042915,
#        -0.04775237, -0.05580506,  0.05877866, -0.01749666, -0.09560552,
#         0.00212355, -0.0141921 , -0.14453167, -0.05154118,  0.07468615,
#        -0.04211344,  0.08071439, -0.13235064, -0.01258701,  0.03046091,
#        -0.0392338 ,  0.03374587, -0.06783652, -0.02991305,  0.02026355,
#        -0.00508234, -0.06426658,  0.06245873,  0.02209905, -0.041567  ,
#         0.08121882, -0.04247131,  0.08651373, -0.02928636,  0.1229988 ,
#        -0.07991014, -0.11973334, -0.1315808 , -0.07672812, -0.09474719,
#         0.03710532, -0.00540135, -0.05086038, -0.10079338,  0.00783374,
#        -0.03282944,  0.02283455, -0.03340745,  0.01516942, -0.04736314,
#         0.06563643,  0.01164983, -0.03974514,  0.05859199, -0.02848689,
#         0.07675906, -0.00518726,  0.01408636,  0.06156234, -0.08461656,
#         0.0670941 , -0.04302203, -0.00531821,  0.08658073,  0.01766698,
#        -0.0158153 , -0.03386029, -0.05939994,  0.00026101,  0.10157829,
#         0.00442124,  0.04888909,  0.02728619, -0.03687223, -0.16503823,
#        -0.07535471,  0.11444187,  0.04524922, -0.02188888, -0.06267868,
#         0.03939132,  0.0310744 ,  0.1029609 , -0.05829212, -0.05350414,
#         0.02396713, -0.00710773,  0.01986691,  0.01470287, -0.00201423,
#        -0.10398582,  0.04355647,  0.07516445, -0.01645024,  0.15114844,
#        -0.03213815,  0.10502552,  0.03645592, -0.11729215, -0.07210695,
#        -0.006096  , -0.03091427,  0.04029511,  0.02021004,  0.01973336,
#        -0.03016801, -0.00448219,  0.0483647 ,  0.02820652,  0.09023244,
#         0.08390046,  0.1040727 ,  0.09461734,  0.03327115,  0.14623354,
#         0.15700692,  0.00040127,  0.00093942,  0.06236507, -0.06556632],
#       dtype=float32)

# %% [markdown]
# ### Comparing the Dataset and Lexicon Vocabulary

# %%
### Finding the vocabulary of the dataset
vocab = wv_model.wv.index_to_key

# %%
len(vocab)
# Out:
# 39276

# %%
### Finding the Emolex vocabulary.
emotions = edf["word"]
words_emotions = list(chain(*emotions.apply(word_tokenize)))

# List of words with count higher that the threshold ie 1
words_emotions = [w.lower() for w in words_emotions]
word_counts = Counter(words_emotions)
words_emotions = [k for k,v in word_counts.items() if v >= 1]

words_emotions
# Out:
# ['outraged',
#  'brutality',
#  'hatred',
#  'hateful',
#  'terrorize',
#  'infuriated',
#  'violently',
#  'furious',
#  'enraged',
#  'furiously',
#  'screwyou',
#  'murderer',
#  'fury',
#  'execution',
#  'angered',
#  'savagery',
#  'slaughtering',
#  'veryangry',
#  'assassinate',
#  'fuckoff',
#  'annihilation',
#  'rage',
#  'loathe',
#  'damnation',
#  'roadrage',
#  'fucktard',
#  'homicidal',
#  'furor',
#  'hostile',
#  'annihilate',
#  'murder',
#  'raging',
#  'sopissed',
#  'pissed',
#  'rape',
#  'explosive',
#  'obliterated',
#  'vengeful',
#  'ferocious',
#  'infuriates',
#  'killing',
#  'combative',
#  'gofuckyourself',
#  'vengeance',
#  'wrath',
#  'torment',
#  'vicious',
#  'threatening',
#  'massacre',
#  'bloodthirsty',
#  'abhorrent',
#  'pissoff',
#  'fighting',
#  'annihilated',
#  'attacking',
#  'angriest',
#  'bloodshed',
#  'smite',
#  'brawl',
#  'assault',
#  'assassination',
#  'strangle',
#  'explode',
#  'malicious',
#  'tirade',
#  'hostility',
#  'loathsome',
#  'attack',
#  'hell',
#  'murderous',
#  'malice',
#  'terrorism',
#  'beating',
#  'pissingmeoff',
#  'desecration',
#  'outrage',
#  'irate',
#  'tumultuous',
#  'destroying',
#  'violent',
#  'stab',
#  'infuriate',
#  'slaughter',
#  'abomination',
#  'obliterate',
#  'dumbbitch',
#  'belligerent',
#  'detest',
#  'hostilities',
#  'prick',
#  'cruelty',
#  'horrid',
#  'rampage',
#  'rabid',
#  'torture',
#  'satanic',
#  'hate',
#  'hating',
#  'tyrannical',
#  'demonic',
#  'ragemode',
#  'despicable',
#  'ruinous',
#  'condemn',
#  'extermination',
#  'riots',
#  'dickhead',
#  'angry',
#  'demolish',
#  'livid',
#  'madman',
#  'vindictive',
#  'ferocity',
#  'terrorist',
#  'venomous',
#  'threaten',
#  'hateyou',
#  'effyou',
#  'abhor',
#  'carnage',
#  'savage',
#  'atrocity',
#  'fuming',
#  'pissedoff',
#  'pissesmeoff',
#  'fierce',
#  'abuse',
#  'barbaric',
#  'berserk',
#  'fucksake',
#  'vendetta',
#  'angrytweet',
#  'destroyer',
#  'tyrant',
#  'anger',
#  'pieceofshit',
#  'slam',
#  'punching',
#  'homicide',
#  'punched',
#  'bitch',
#  'fights',
#  'destructive',
#  'ruthless',
#  'villainous',
#  'slap',
#  'destroyed',
#  'ragetweet',
#  'slaughterhouse',
#  'retaliatory',
#  'yelling',
#  'riot',
#  'punishing',
#  'growthefuckup',
#  'diabolical',
#  'clash',
#  'manslaughter',
#  'hellish',
#  'bloody',
#  'loath',
#  'quarrel',
#  'detonation',
#  'sinister',
#  'fumin',
#  'hateeee',
#  'treacherous',
#  'accusing',
#  'madder',
#  'retaliate',
#  'revulsion',
#  'horrific',
#  'scorn',
#  'bomb',
#  'deplorable',
#  'anarchist',
#  'devastation',
#  'resent',
#  'firestorm',
#  'contemptible',
#  'shittest',
#  'smash',
#  'deadly',
#  'soangry',
#  'rant',
#  'cruel',
#  'outburst',
#  'snarl',
#  'crazed',
#  'dontmesswithme',
#  'profane',
#  'aggravating',
#  'douchebags',
#  'offend',
#  'horror',
#  'revolting',
#  'despise',
#  'vulgarity',
#  'growling',
#  'stfu',
#  'molestation',
#  'fuckedoff',
#  'erupt',
#  'violence',
#  'horrible',
#  'screaming',
#  'threat',
#  'bastards',
#  'revenge',
#  'menacing',
#  'crushing',
#  'damn',
#  'catastrophe',
#  'demon',
#  'argue',
#  'fedup',
#  'vehement',
#  'thrash',
#  'warfare',
#  'revolt',
#  'flog',
#  'deplore',
#  'persecute',
#  'riotous',
#  'altercation',
#  'warlike',
#  'mutiny',
#  'shitday',
#  'sabotage',
#  'castrate',
#  'strike',
#  'malevolent',
#  'disaster',
#  'disastrous',
#  'disdain',
#  'choke',
#  'arseholes',
#  'devil',
#  'scream',
#  'spiteful',
#  'bastarding',
#  'scorching',
#  'horseshit',
#  'treachery',
#  'slay',
#  'brutal',
#  'tumult',
#  'madden',
#  'aggravates',
#  'vermin',
#  'anarchism',
#  'mutilation',
#  'mangle',
#  'criminal',
#  'punch',
#  'denunciation',
#  'holocaust',
#  'blasphemous',
#  'battled',
#  'dumbasses',
#  'fatal',
#  'virulence',
#  'dontlikeyou',
#  'hurting',
#  'crucifixion',
#  'deranged',
#  'evil',
#  'irritated',
#  'atrocious',
#  'assassin',
#  'intimidation',
#  'persecution',
#  'slayer',
#  'kidnap',
#  'dicks',
#  'scolding',
#  'aggravated',
#  'aggression',
#  'armed',
#  'poison',
#  'snarling',
#  'venom',
#  'battle',
#  'disgruntled',
#  'assailant',
#  'insidious',
#  'resentment',
#  'contemptuous',
#  'lynch',
#  'lunatic',
#  'mad',
#  'peeved',
#  'bully',
#  'temper',
#  'infanticide',
#  'curse',
#  'domination',
#  'imprisonment',
#  'terrible',
#  'disparage',
#  'makesmemad',
#  'volatility',
#  'eradication',
#  'scoundrel',
#  'eradicate',
#  'tantrum',
#  'devastate',
#  'agitation',
#  'aggressively',
#  'irritates',
#  'dictatorship',
#  'profanity',
#  'dastardly',
#  'expletive',
#  'wreak',
#  'contempt',
#  'crime',
#  'poisonous',
#  'nasty',
#  'aggravation',
#  'condemnation',
#  'egregious',
#  'shove',
#  'shoot',
#  'shot',
#  'crushed',
#  'corrupting',
#  'harmful',
#  'cruelly',
#  'maniac',
#  'irritable',
#  'shooting',
#  'odious',
#  'shout',
#  'eruption',
#  'cutthroat',
#  'kick',
#  'hateeveryone',
#  'hit',
#  'fight',
#  'enemy',
#  'combat',
#  'aggressive',
#  'punished',
#  'yell',
#  'ambush',
#  'harass',
#  'gore',
#  'expel',
#  'malignant',
#  'destruction',
#  'aggressor',
#  'incense',
#  'grudge',
#  'antichrist',
#  'cranky',
#  'reprisal',
#  'slave',
#  'growl',
#  'offended',
#  'clashing',
#  'insulting',
#  'insurrection',
#  'spank',
#  'animosity',
#  'denounce',
#  'growls',
#  'executioner',
#  'twat',
#  'doomsday',
#  'bombard',
#  'feud',
#  'accused',
#  'arson',
#  'daemon',
#  'shackle',
#  'indignant',
#  'obscenity',
#  'spat',
#  'havoc',
#  'grr',
#  'inexcusable',
#  'expulsion',
#  'reprimand',
#  'somad',
#  'poisoned',
#  'kicking',
#  'wound',
#  'batter',
#  'frustrated',
#  'hanging',
#  'disgusting',
#  'spanking',
#  'suicidal',
#  'anarchy',
#  'glaring',
#  'combatant',
#  'wrecked',
#  'inflict',
#  'grievous',
#  'cheat',
#  'prosecute',
#  'agitated',
#  'swastika',
#  'enslaved',
#  'scourge',
#  'raid',
#  'suffocation',
#  'defamatory',
#  'indict',
#  'cursing',
#  'provocation',
#  'harassing',
#  'injure',
#  'betray',
#  'thundering',
#  'strife',
#  'arsehole',
#  'jerk',
#  'retaliation',
#  'fiend',
#  'theft',
#  'insane',
#  'irritate',
#  'deprivation',
#  'convict',
#  'cussed',
#  'turmoil',
#  'smack',
#  'retribution',
#  'adverse',
#  'battery',
#  'twats',
#  'collision',
#  'injurious',
#  'rebellion',
#  'slavery',
#  'gang',
#  'irritability',
#  'bitterly',
#  'oppressor',
#  'antagonism',
#  'intolerable',
#  'disgraced',
#  'diatribe',
#  'sickening',
#  'ranting',
#  'asshole',
#  'irks',
#  'irritating',
#  'discrimination',
#  'bombardment',
#  'thug',
#  'antagonistic',
#  'revolution',
#  'blast',
#  'frustrate',
#  'tension',
#  'manipulation',
#  'oppression',
#  'hurtful',
#  'insult',
#  'tiredofit',
#  'bigot',
#  'disgust',
#  'spite',
#  'intrusive',
#  'harshness',
#  'slur',
#  'bitterness',
#  'tempest',
#  'miserable',
#  'morbidity',
#  'assail',
#  'puncture',
#  'invasion',
#  'inferno',
#  'casualty',
#  'storming',
#  'wretch',
#  'consternation',
#  'guillotine',
#  'forcibly',
#  'overpowering',
#  'immoral',
#  'guilty',
#  'depraved',
#  'raving',
#  'soannoyed',
#  'recalcitrant',
#  'accursed',
#  'screwed',
#  'invader',
#  'scare',
#  'indignation',
#  'jealousy',
#  'vexed',
#  'confront',
#  'brute',
#  'throttle',
#  'provoking',
#  'coup',
#  'pillage',
#  'damage',
#  'shutup',
#  'contentious',
#  'shutit',
#  'bickering',
#  'incarceration',
#  'butcher',
#  'lash',
#  'conflict',
#  'blaze',
#  'slut',
#  'defiant',
#  'wreck',
#  'revolver',
#  'yousuck',
#  'criminality',
#  'cancer',
#  'frustration',
#  'standoff',
#  'gory',
#  'dontmess',
#  'alienation',
#  'gun',
#  'pernicious',
#  'grope',
#  'discord',
#  'condescension',
#  'discriminate',
#  'blasphemy',
#  'chaotic',
#  'disturbance',
#  'friggen',
#  'jab',
#  'monstrosity',
#  'lunacy',
#  'oppressive',
#  'scandalous',
#  'cursed',
#  'sneer',
#  'death',
#  'shit',
#  'slash',
#  'unfair',
#  'disparaging',
#  'gallows',
#  'escalate',
#  'intolerant',
#  'lawlessness',
#  'bluddy',
#  'dreadful',
#  'arghh',
#  'derogatory',
#  'beast',
#  'malign',
#  'traitor',
#  'grouchy',
#  'slander',
#  'wrangling',
#  'taunt',
#  'perdition',
#  'frightful',
#  'invade',
#  'glare',
#  'deceived',
#  'torpedo',
#  'bellows',
#  'retards',
#  'bearish',
#  'rave',
#  'hurt',
#  'grating',
#  'thief',
#  'uncontrollable',
#  'idiots',
#  'devastating',
#  'banshee',
#  'cross',
#  'betrayal',
#  'fits',
#  'shatter',
#  'conflagration',
#  'jeopardize',
#  'dissension',
#  'subjugation',
#  'disturbed',
#  'stomped',
#  'grab',
#  'ticked',
#  'masochism',
#  'grievance',
#  'defiance',
#  'blackmail',
#  'offensive',
#  'decry',
#  'sin',
#  'fustrated',
#  'ire',
#  'confine',
#  'deceive',
#  'arghhhh',
#  'punishment',
#  'violation',
#  'preposterous',
#  'disgraceful',
#  'darkside',
#  'frustrates',
#  'overbearing',
#  'misery',
#  'firearms',
#  'rebel',
#  'shrill',
#  'disparity',
#  'hadenough',
#  'stolen',
#  'foul',
#  'adversary',
#  'conspirator',
#  'skirmish',
#  'ruined',
#  'annoyin',
#  'menace',
#  'tackle',
#  'humiliate',
#  'prejudice',
#  'resentful',
#  'antagonist',
#  'heated',
#  'wanker',
#  'callous',
#  'argument',
#  'sting',
#  'outcry',
#  'grumble',
#  'robbery',
#  'entangled',
#  'resistance',
#  'irreconcilable',
#  'obstructive',
#  'dismay',
#  'mob',
#  'juststop',
#  'badness',
#  'ridicule',
#  'incendiary',
#  'flares',
#  'twofaced',
#  'exacerbation',
#  'prejudicial',
#  'unbridled',
#  'intruder',
#  'communism',
#  'uprising',
#  'dispute',
#  'reckless',
#  'confinement',
#  'degeneracy',
#  'whip',
#  'belittle',
#  'allegation',
#  'offender',
#  'tackled',
#  'dictatorial',
#  'perversion',
#  'unjust',
#  'fiesty',
#  'hassle',
#  'unjustifiable',
#  'bigoted',
#  'dissonance',
#  'prison',
#  'trespass',
#  'cantstandit',
#  'hot',
#  'renegade',
#  'suicide',
#  'annoy',
#  'leavemealone',
#  'depravity',
#  'venting',
#  'divorce',
#  'dishonest',
#  'prisoner',
#  'duress',
#  'inimical',
#  'grrr',
#  'idiotic',
#  'treason',
#  'tortious',
#  'criticize',
#  'disrespectful',
#  'distrust',
#  'cretins',
#  'broil',
#  'hangry',
#  'unkind',
#  'bile',
#  'roar',
#  'poaching',
#  'unforgiving',
#  'poachers',
#  'pow',
#  'unleash',
#  'scold',
#  'argumentation',
#  'chaos',
#  'frustrating',
#  'jerks',
#  'coercion',
#  'grump',
#  'victimized',
#  'tussle',
#  'bane',
#  'accusation',
#  'enmity',
#  'repudiation',
#  'banish',
#  'disfigured',
#  'storm',
#  'derogation',
#  'obstruct',
#  'nobodycares',
#  'rejects',
#  'unruly',
#  'crazy',
#  'hammering',
#  'malpractice',
#  'frenzied',
#  'suppression',
#  'scoff',
#  'possessed',
#  'intractable',
#  'fervor',
#  'delusional',
#  'brunt',
#  'confined',
#  'injustice',
#  'shun',
#  'defy',
#  'anguish',
#  'antithesis',
#  'fear',
#  'bout',
#  'derision',
#  'banished',
#  'animus',
#  'reject',
#  'spear',
#  'dominate',
#  'patronising',
#  'brazen',
#  'disrupting',
#  'ordeal',
#  'foaming',
#  'getoveryourself',
#  'stupidpeople',
#  'toughness',
#  'sinful',
#  'madness',
#  'oppress',
#  'avarice',
#  'anathema',
#  'incest',
#  'dissident',
#  'abolish',
#  'smuggler',
#  'claw',
#  'revoke',
#  'complaint',
#  'infraction',
#  'avenger',
#  'pervert',
#  'cutting',
#  'usurp',
#  'inhuman',
#  'disservice',
#  'annoyed',
#  'stayaway',
#  'disobedient',
#  'alienate',
#  'fricking',
#  'demand',
#  'disapproved',
#  'oust',
#  'litigious',
#  'rivalry',
#  'mocking',
#  'obnoxious',
#  'thresh',
#  'restrain',
#  'blame',
#  'deceit',
#  'strained',
#  'penalty',
#  'opposed',
#  'disgrace',
#  'imprisoned',
#  'sucker',
#  'suspicious',
#  'upheaval',
#  'renounce',
#  'turbulence',
#  'pound',
#  'coldness',
#  'ungrateful',
#  'stoopid',
#  'battalion',
#  'armament',
#  'jealous',
#  'hostage',
#  'adversity',
#  'infidel',
#  'ram',
#  'annoying',
#  'dispossessed',
#  'feudalism',
#  'gall',
#  'accuser',
#  'friction',
#  'subversion',
#  'plunder',
#  'incite',
#  'objection',
#  'simmer',
#  'offense',
#  'complain',
#  'injury',
#  'disruption',
#  'backoff',
#  'steal',
#  'angermanagement',
#  'stifled',
#  'smother',
#  'selfish',
#  'dislike',
#  'recidivism',
#  'disobey',
#  'intolerance',
#  'exile',
#  'thump',
#  'selfishness',
#  'distress',
#  'huff',
#  'perpetrator',
#  'subversive',
#  'opposition',
#  'insanity',
#  'areyoukidding',
#  'mug',
#  'agony',
#  'arrogant',
#  'vent',
#  'sux',
#  'picketing',
#  'elimination',
#  'haughty',
#  'troublesome',
#  'mislead',
#  'impermeable',
#  'illegality',
#  'constraint',
#  'dying',
#  'clamor',
#  'flagrant',
#  'illicit',
#  'busted',
#  'veto',
#  'idiocy',
#  'crabby',
#  'stubbed',
#  'grated',
#  'desist',
#  'suppress',
#  'bad',
#  'disagreeing',
#  'struggle',
#  'despotism',
#  'disapproving',
#  'bayonet',
#  'intense',
#  'hysterical',
#  'usurped',
#  'displeased',
#  'godless',
#  'unlawful',
#  'wrongly',
#  'repellent',
#  'wrongful',
#  'dishonor',
#  'foe',
#  'wasted',
#  'psychosis',
#  'aversion',
#  'punitive',
#  'ultimatum',
#  'gahhh',
#  'knuckles',
#  'effigy',
#  'upset',
#  'schism',
#  'separatist',
#  'deny',
#  'stupidity',
#  'deleterious',
#  'worthless',
#  'abandonment',
#  'mucked',
#  'ransom',
#  'irritation',
#  'fugitive',
#  'segregate',
#  'oblivion',
#  'payback',
#  'incongruous',
#  'eviction',
#  'collusion',
#  'rob',
#  'ravenous',
#  'infidelity',
#  'overrun',
#  'rejection',
#  'stupidrain',
#  'getoverit',
#  'incredulous',
#  'martial',
#  'harbinger',
#  'painful',
#  'defense',
#  'enforce',
#  'fuss',
#  'banger',
#  'defraud',
#  'commotion',
#  'powerful',
#  'fraudulent',
#  'concealment',
#  'indecency',
#  'greed',
#  'exasperation',
#  'disobedience',
#  'censor',
#  'discontent',
#  'fallacious',
#  'gonorrhea',
#  'unsympathetic',
#  'cur',
#  'duel',
#  'banishment',
#  'annoyance',
#  'bang',
#  'deportation',
#  'penetration',
#  'nettle',
#  'scar',
#  'misrepresented',
#  'penitentiary',
#  'sedition',
#  'barb',
#  'snubbed',
#  'sarcasm',
#  'cracked',
#  'blatant',
#  'force',
#  'perverse',
#  'wring',
#  'grim',
#  'bastion',
#  'tiff',
#  'sordid',
#  'surly',
#  'nothappy',
#  'moody',
#  'hunting',
#  'indenture',
#  'detainee',
#  'supremacy',
#  'compulsion',
#  'reproach',
#  'areyoukiddingme',
#  'inept',
#  'cantwin',
#  'squelch',
#  'forfeit',
#  'blockade',
#  'disappoint',
#  'implicate',
#  'sham',
#  'awful',
#  'contradict',
#  'sneak',
#  'lying',
#  'badger',
#  'forsaken',
#  'antipathy',
#  'inequality',
#  'epidemic',
#  'wop',
#  'onerous',
#  'tremor',
#  ...]

# %%
common_words = [w for w in vocab if w in words_emotions]
common_words
# Out:
# ['good',
#  'like',
#  'time',
#  'cable',
#  'lens',
#  'long',
#  'case',
#  'recommend',
#  'problem',
#  'music',
#  'battery',
#  'found',
#  'light',
#  'home',
#  'love',
#  'money',
#  'pretty',
#  'fit',
#  'excellent',
#  'less',
#  'down',
#  'books',
#  'perfect',
#  'system',
#  'bad',
#  'happy',
#  'simple',
#  'full',
#  'life',
#  'store',
#  'free',
#  'network',
#  'turn',
#  'thought',
#  'wear',
#  'top',
#  'fact',
#  'deal',
#  'mine',
#  'pay',
#  'running',
#  'compact',
#  'real',
#  'install',
#  'run',
#  'manual',
#  'experience',
#  'expect',
#  'finally',
#  'wireless',
#  'help',
#  'cover',
#  'monster',
#  'fits',
#  'level',
#  'visor',
#  'service',
#  'expected',
#  'break',
#  'change',
#  'warranty',
#  'larger',
#  'label',
#  'clean',
#  'kind',
#  'start',
#  'weight',
#  'durable',
#  'guess',
#  'live',
#  'travel',
#  'pleased',
#  'machine',
#  'watch',
#  'difficult',
#  'strong',
#  'comfort',
#  'save',
#  'disappointed',
#  'super',
#  'adjust',
#  'mind',
#  'true',
#  'important',
#  'instructions',
#  'surge',
#  'matter',
#  'lost',
#  'enjoy',
#  'show',
#  'reliable',
#  'together',
#  'bottom',
#  'prefer',
#  'movies',
#  'fairly',
#  'wonderful',
#  'provide',
#  'immediately',
#  'lower',
#  'leave',
#  'favorite',
#  'professional',
#  'hope',
#  'complaint',
#  'glad',
#  'purpose',
#  'star',
#  'satisfied',
#  'limited',
#  'noble',
#  'friend',
#  'fun',
#  'surprised',
#  'friends',
#  'wait',
#  'gift',
#  'broke',
#  'rest',
#  'brother',
#  'annoying',
#  'crisp',
#  'lose',
#  'shoot',
#  'protector',
#  'trip',
#  'coming',
#  'fully',
#  'plan',
#  'rating',
#  'word',
#  'accurate',
#  'strip',
#  'hearing',
#  'suggest',
#  'clarity',
#  'center',
#  'shot',
#  'gone',
#  'remove',
#  'lifetime',
#  'christmas',
#  'family',
#  'personal',
#  'unfortunately',
#  'share',
#  'blue',
#  'cradle',
#  'fall',
#  'hot',
#  'ready',
#  'hit',
#  'incredible',
#  'daily',
#  'track',
#  'moving',
#  'broken',
#  'base',
#  'weak',
#  'powerful',
#  'worry',
#  'shooting',
#  'fire',
#  'general',
#  'series',
#  'giving',
#  'negative',
#  'luck',
#  'ease',
#  'careful',
#  'serial',
#  'eventually',
#  'lights',
#  'pain',
#  'fixed',
#  'constantly',
#  'rebel',
#  'missing',
#  'waste',
#  'quiet',
#  'helpful',
#  'pressure',
#  'special',
#  'avoid',
#  'terms',
#  'died',
#  'loved',
#  'capacity',
#  'chance',
#  'budget',
#  'dark',
#  'happen',
#  'secure',
#  'balance',
#  'alone',
#  'durability',
#  'hurt',
#  'classical',
#  'daughter',
#  'info',
#  'worse',
#  'expecting',
#  'surprisingly',
#  'complain',
#  'beautiful',
#  'improvement',
#  'improve',
#  'credit',
#  'impossible',
#  'pop',
#  'school',
#  'complete',
#  'worn',
#  'words',
#  'doubt',
#  'loss',
#  'intended',
#  'waiting',
#  'addresses',
#  'default',
#  'automatic',
#  'hate',
#  'highest',
#  'superb',
#  'living',
#  'belt',
#  'admit',
#  'guide',
#  'warm',
#  'isolation',
#  'ram',
#  'create',
#  'bargain',
#  'result',
#  'mobile',
#  'date',
#  'miss',
#  'supports',
#  'account',
#  'damage',
#  'husband',
#  'tool',
#  'wonder',
#  'fault',
#  'defective',
#  'operation',
#  'late',
#  'hassle',
#  'follow',
#  'outstanding',
#  'spending',
#  'positive',
#  'steady',
#  'entertainment',
#  'motion',
#  'leaving',
#  'noisy',
#  'continue',
#  'concerned',
#  'popular',
#  'surprise',
#  'fancy',
#  'stable',
#  'muddy',
#  'regret',
#  'friendly',
#  'truck',
#  'green',
#  'experienced',
#  'pilot',
#  'crazy',
#  'ugly',
#  'terrific',
#  'outdoors',
#  'wet',
#  'deluxe',
#  'terrible',
#  'walking',
#  'trust',
#  'feeling',
#  'lines',
#  'fell',
#  'safe',
#  'present',
#  'mistake',
#  'interested',
#  'effective',
#  'grab',
#  'frustrating',
#  'bonus',
#  'wanting',
#  'slip',
#  'content',
#  'baby',
#  'advice',
#  'vacation',
#  'reliability',
#  'fragile',
#  'error',
#  'worried',
#  'breeze',
#  'shack',
#  'clock',
#  'alarm',
#  'sharing',
#  'accidentally',
#  'rooted',
#  'board',
#  'win',
#  'shopping',
#  'hanging',
#  'party',
#  'abuse',
#  'delivery',
#  'tough',
#  'falling',
#  'horrible',
#  'failure',
#  'mess',
#  'surround',
#  'art',
#  'obvious',
#  'occasional',
#  'morning',
#  'title',
#  'nature',
#  'public',
#  'steal',
#  'hiking',
#  'happier',
#  'mail',
#  'calls',
#  'fidelity',
#  'crap',
#  'exchange',
#  'font',
#  'dynamic',
#  'usual',
#  'awful',
#  'pleasure',
#  'responsive',
#  'die',
#  'beach',
#  'sun',
#  'fill',
#  'constant',
#  'ship',
#  'force',
#  'prevent',
#  'cash',
#  'efficient',
#  'exception',
#  'catch',
#  'cartridge',
#  'kid',
#  'weird',
#  'shame',
#  'depth',
#  'planning',
#  'holder',
#  'overpriced',
#  'differences',
#  'losing',
#  'beware',
#  'buck',
#  'dirty',
#  'ground',
#  'seal',
#  'bang',
#  'sweet',
#  'favor',
#  'trick',
#  'vision',
#  'musical',
#  'receiving',
#  'child',
#  'comfy',
#  'pleasant',
#  'protected',
#  'accept',
#  'regardless',
#  'thrilled',
#  'wont',
#  'delay',
#  'flaw',
#  'neutral',
#  'trash',
#  'summer',
#  'instruction',
#  'shoulder',
#  'lowest',
#  'unable',
#  'pure',
#  'diamond',
#  'risk',
#  'critical',
#  'tear',
#  'versus',
#  'production',
#  'suspect',
#  'warning',
#  'dirt',
#  'protective',
#  'strength',
#  'manage',
#  'choices',
#  'cutting',
#  'expert',
#  'honest',
#  'attempt',
#  'cap',
#  'peace',
#  'custom',
#  'suddenly',
#  'discomfort',
#  'difficulty',
#  'opposed',
#  'proof',
#  'excited',
#  'jump',
#  'worthless',
#  'inferior',
#  'camping',
#  'edition',
#  'rip',
#  'competition',
#  'brilliant',
#  'amazingly',
#  'angry',
#  'success',
#  'bias',
#  'distorted',
#  'wonderfully',
#  'wind',
#  'guarantee',
#  'father',
#  'stolen',
#  'sucks',
#  'coffee',
#  'garbage',
#  'cumbersome',
#  'whip',
#  'magic',
#  'unique',
#  'flaws',
#  'fear',
#  'enjoying',
#  'explain',
#  'familiar',
#  'god',
#  'providing',
#  'management',
#  'serve',
#  'prepared',
#  'electric',
#  'hiss',
#  'gain',
#  'sweat',
#  'ridiculous',
#  'pleasing',
#  'treat',
#  'disappointing',
#  'companion',
#  'excel',
#  'majority',
#  'gray',
#  'shell',
#  'december',
#  'related',
#  'silly',
#  'punch',
#  'winner',
#  'laser',
#  'fashion',
#  'necessarily',
#  'fabulous',
#  'calculator',
#  'tension',
#  'stress',
#  'japan',
#  'rain',
#  'count',
#  'relative',
#  'forced',
#  'easiest',
#  'pin',
#  'magnet',
#  'cancellation',
#  'cold',
#  'bank',
#  'mother',
#  'lightning',
#  'badly',
#  'develop',
#  'lucky',
#  'frustration',
#  'offering',
#  'afraid',
#  'identify',
#  'birthday',
#  'memories',
#  'enable',
#  'joy',
#  'hype',
#  'neighborhood',
#  'brighter',
#  'lying',
#  'crash',
#  'sticky',
#  'backwards',
#  'friday',
#  'cracked',
#  'remains',
#  'sore',
#  'objective',
#  'wasted',
#  'modify',
#  'simplicity',
#  'destroyed',
#  'painful',
#  'gon',
#  'empty',
#  'glare',
#  'policy',
#  'cabinet',
#  'blame',
#  'dictionary',
#  'gem',
#  'irritating',
#  'trade',
#  'heart',
#  'faulty',
#  'ultimately',
#  'intend',
#  'demand',
#  'gently',
#  'happily',
#  'football',
#  'resistant',
#  'snag',
#  'rave',
#  'proven',
#  'elite',
#  'disappointment',
#  'sadly',
#  'homework',
#  'elegant',
#  'challenge',
#  'emergency',
#  'woods',
#  'damn',
#  'refused',
#  'hunting',
#  'console',
#  'synchronize',
#  'bug',
#  'convinced',
#  'contains',
#  'patience',
#  'weekend',
#  'thief',
#  'accident',
#  'enthusiast',
#  'bounce',
#  'wan',
#  'strange',
#  'letter',
#  'desire',
#  'randomly',
#  'fool',
#  'erase',
#  'opportunity',
#  'fitting',
#  'unacceptable',
#  'hide',
#  'relief',
#  'ultimate',
#  'truth',
#  'disappoint',
#  'annoyance',
#  'magnetic',
#  'forgotten',
#  'sad',
#  'failing',
#  'liking',
#  'endless',
#  'gifts',
#  'exercise',
#  'advance',
#  'cobra',
#  'hurting',
#  'warned',
#  'hell',
#  'separation',
#  'regard',
#  'rapid',
#  'remarkable',
#  'advise',
#  'tax',
#  'inability',
#  'lesser',
#  'beauty',
#  'defect',
#  'cross',
#  'frustrated',
#  'sick',
#  'trusted',
#  'respect',
#  'relax',
#  'mouth',
#  'workout',
#  'procedure',
#  'confidence',
#  'matters',
#  'qualities',
#  'coax',
#  'communicate',
#  'ruined',
#  'surprising',
#  'signature',
#  'dislike',
#  'blast',
#  'worrying',
#  'rely',
#  'protecting',
#  'perfection',
#  'isolate',
#  'overwhelming',
#  'measured',
#  'airport',
#  'alive',
#  'overpowering',
#  'locate',
#  'caution',
#  'kill',
#  'straightforward',
#  'couch',
#  'rack',
#  'classics',
#  'cutter',
#  'energy',
#  'death',
#  'supporting',
#  'weigh',
#  'unhappy',
#  'loudness',
#  'hood',
#  'church',
#  'worthy',
#  'trees',
#  'understanding',
#  'disconnect',
#  'grey',
#  'exceed',
#  'experiment',
#  'kick',
#  'mountain',
#  'vivid',
#  'gorgeous',
#  'reputable',
#  'disappear',
#  'lie',
#  'don',
#  'improves',
#  'spectacular',
#  'flying',
#  'neighbor',
#  'curious',
#  'appreciated',
#  'treadmill',
#  'fuss',
#  'county',
#  'terribly',
#  'insulation',
#  'opera',
#  'tighten',
#  'compensate',
#  'wasting',
#  'drown',
#  'mistakes',
#  'bubble',
#  'circumstances',
#  'proxy',
#  'lake',
#  'wound',
#  'accepts',
#  'perspective',
#  'isolated',
#  'nose',
#  'hobby',
#  'screwed',
#  'disable',
#  'sunny',
#  'sacrifice',
#  'possibility',
#  'deserve',
#  'maintenance',
#  'grow',
#  'disconnected',
#  'praise',
#  'delight',
#  'satisfying',
#  'mountains',
#  'weakness',
#  'unreliable',
#  'dull',
#  'cancel',
#  'advised',
#  'disabled',
#  'headaches',
#  'fat',
#  'nasty',
#  'appeal',
#  'achieve',
#  'planes',
#  'storm',
#  'hurry',
#  'shove',
#  'fooled',
#  'withstand',
#  'smell',
#  'grounded',
#  'path',
#  'delighted',
#  'row',
#  'law',
#  'helmet',
#  'assembly',
#  'vista',
#  'necessity',
#  'promise',
#  'clumsy',
#  'shaky',
#  'ghost',
#  'communication',
#  'nervous',
#  'launch',
#  'inconvenient',
#  'destination',
#  'strike',
#  'clue',
#  'certified',
#  'nightmare',
#  'explore',
#  'lean',
#  'interior',
#  'shock',
#  'shortly',
#  'beating',
#  'raid',
#  'misleading',
#  'alas',
#  'confident',
#  'dream',
#  'organization',
#  'gentle',
#  'giant',
#  'loving',
#  'smile',
#  'aesthetics',
#  'upset',
#  'painfully',
#  'pound',
#  'assist',
#  'overcome',
#  'attest',
#  'score',
#  'slave',
#  'tree',
#  'circle',
#  'depend',
#  'bummer',
#  'presents',
#  'tomorrow',
#  'glow',
#  'arrive',
#  'compress',
#  'exciting',
#  'assured',
#  'arrival',
#  'competitive',
#  'secret',
#  'successful',
#  'forum',
#  'horse',
#  'leaning',
#  'lovely',
#  'lesson',
#  'buzzing',
#  'dazzle',
#  'compass',
#  'modest',
#  'doctor',
#  'heft',
#  'deteriorate',
#  'john',
#  'bookstore',
#  'regrets',
#  'draining',
#  'favorable',
#  'accomplished',
#  'worthwhile',
#  'wizard',
#  'bear',
#  'puppy',
#  'ill',
#  'rule',
#  'progress',
#  'unfortunate',
#  'gun',
#  'judge',
#  'wild',
#  'glowing',
#  'unsure',
#  'teacher',
#  'medical',
#  'symphony',
#  'emphasize',
#  'annoyed',
#  'criticism',
#  'doubts',
#  'vulnerable',
#  'satisfy',
#  'ribbon',
#  'fuse',
#  'author',
#  'pivot',
#  'aberration',
#  'lover',
#  'accidental',
#  'whine',
#  'resistance',
#  'thumping',
#  'dangerous',
#  'collapse',
#  'insane',
#  'holiday',
#  'passwords',
#  'independent',
#  'sluggish',
#  'variable',
#  'argue',
#  'heaven',
#  'confirmed',
#  'attack',
#  'kudos',
#  'sunset',
#  'precious',
#  'leap',
#  'unknown',
#  'wary',
#  'quicken',
#  'responsible',
#  'idiot',
#  'accepted',
#  'trance',
#  'freedom',
#  'sudden',
#  'buzz',
#  'wedding',
#  'dying',
#  'clearance',
#  'food',
#  'dolphin',
#  'teach',
#  'plunge',
#  'routine',
#  'xmas',
#  'theft',
#  'translation',
#  'award',
#  'weaknesses',
#  'shaking',
#  'generous',
#  'disagree',
#  'respectable',
#  'holidays',
#  'fellow',
#  'troubles',
#  'goodness',
#  'genuine',
#  'aunt',
#  'promises',
#  'leading',
#  'university',
#  'regretted',
#  'hesitation',
#  'beam',
#  'engaging',
#  'sag',
#  'wart',
#  'overbearing',
#  'spine',
#  'sweating',
#  'crippled',
#  'dance',
#  'advent',
#  'inspection',
#  'anticipate',
#  'swamp',
#  'magnificent',
#  'destroying',
#  'struggle',
#  'accounts',
#  'boyfriend',
#  'priceless',
#  'loyal',
#  'accomplish',
#  'offset',
#  'erased',
#  'iron',
#  'goodies',
#  'humble',
#  'touchy',
#  'excitement',
#  'singing',
#  'flood',
#  'aspire',
#  'infinity',
#  'expectation',
#  'kicking',
#  'unexpected',
#  'soul',
#  'fee',
#  'warn',
#  'fade',
#  'united',
#  'expose',
#  'splitting',
#  'official',
#  'cannon',
#  'asap',
#  'ache',
#  'justice',
#  'economy',
#  'incident',
#  'sing',
#  'santa',
#  'laugh',
#  'monochrome',
#  'distracting',
#  'convince',
#  'thx',
#  'pry',
#  'cube',
#  'testament',
#  'spite',
#  'inadequate',
#  'stargazing',
#  'quake',
#  'agreed',
#  'closure',
#  'deteriorated',
#  'torn',
#  'frayed',
#  'questionable',
#  'retract',
#  'cry',
#  'resources',
#  'fulfilled',
#  'leader',
#  'efforts',
#  'peice',
#  'slap',
#  'nest',
#  'beaming',
#  'honor',
#  'squelch',
#  'crude',
#  'pathetic',
#  'buddy',
#  'audience',
#  'insist',
#  'confirmation',
#  'assure',
#  'ruin',
#  'believer',
#  'ware',
#  'guard',
#  'magical',
#  'miracle',
#  'strongest',
#  'hungry',
#  'earned',
#  'swear',
#  'conflict',
#  'grateful',
#  'fortune',
#  'overload',
#  'warrior',
#  'forgiving',
#  'tiff',
#  'sentence',
#  'goofy',
#  'warmth',
#  'outrageous',
#  'flatter',
#  'begun',
#  'mad',
#  'team',
#  ...]

# %%
len(common_words)
# Out:
# 2578

# %% [markdown]
# ### Creating the Cosine Similarity Matrix of Dataset Vocab and Emotion Words

# %%
### For each word in the vocab, we find the similarity between that word and each emotion word. 
### We are only using the words common to both vocabs as they are relevant.

# Calculate the cosine similarity
def cosine_similarity_calc(vec_1,vec_2):
	sim = np.dot(vec_1,vec_2)/(np.linalg.norm(vec_1)*np.linalg.norm(vec_2))
	return sim

similarity_matrix = np.zeros(shape=(len(vocab),len(common_words)))
for ind, word in enumerate(vocab):
    for eind, emotion_word in enumerate(common_words):
        try:
         similarity_matrix[ind][eind] = cosine_similarity_calc(wv_model.wv[word], wv_model.wv[emotion_word])
        except KeyError:
            # print(word, emotion_word)
            pass

# %%
similarity_matrix.shape
# Out:
# (39276, 2578)

# %% [markdown]
# ### Calculating Emotion Word Scores and Weights.

# %%
emotion_words_df = edf[edf["word"].isin(common_words)]
emotion_words_df
# Out:
#             word emotion  emotion-intensity-score
# 5     infuriated   anger                    0.938
# 8        enraged   anger                    0.927
# 12          fury   anger                    0.922
# 14       angered   anger                    0.916
# 21          rage   anger                    0.911
# ...          ...     ...                      ...
# 9888     shatter   trust                    0.172
# 9889  unreliable   trust                    0.172
# 9890      addict   trust                    0.172
# 9896    mistakes   trust                    0.133
# 9897        bait   trust                    0.133
#
# [4309 rows x 3 columns]

# %%
### Ranking emotion words based on the intensity, then assigning a score = 1/rank ie index
emotion_words_df.sort_values(by="emotion-intensity-score", ascending=False, inplace=True)
emotion_words_df = emotion_words_df.reset_index(drop=True)
emotion_words_df
# Out:
#            word  emotion  emotion-intensity-score
# 0      happiest      joy                    0.986
# 1     happiness      joy                    0.984
# 2       torture     fear                    0.984
# 3         bliss      joy                    0.971
# 4      horrific     fear                    0.969
# ...         ...      ...                      ...
# 4304    musical    anger                    0.011
# 4305     lovely  sadness                    0.009
# 4306     liquor  sadness                    0.000
# 4307       tree    anger                    0.000
# 4308        art  sadness                    0.000
#
# [4309 rows x 3 columns]

# %% [markdown]
# ### Creating the Sentiment Aware Word Embeddings

# %%
### For each word in the dataset vocabulary, find the two emotion word with the highest cosine similarity.
### Create the emotion-aware embeddings by multiplying the word vector of the emotion word with the weight.
### Overlay the wv of the original word and the emotion word.

emotion_aware_wv = {}
embedding_range = 2
for ind, word in enumerate(vocab):
        sim_scores = similarity_matrix[ind]
        ind_max = sorted(range(len(sim_scores)), key=lambda x: sim_scores[x])[:embedding_range]

        # Find the scores and weights of the emotion words based on the ranks in the emotion lexicon.
        eweights = []
        for eind in range(embedding_range):
                rank = emotion_words_df[emotion_words_df['word'] == common_words[ind_max[eind]]].index.values[0]
                score = 1/(rank +1)
                weight = similarity_matrix[ind][ind_max[eind]] * score
                eweights.append(weight)

        # Normalize the weights.
        norm_eweights = [w/sum(eweights) for w in eweights]
        
        # Created the emotion word vector as the normalized weighted sum of the vectors of the emotion words.
        ewv = np.zeros(300)
        for eind in range(embedding_range):
                emotion_word = common_words[ind_max[eind]]
                emotion_word_vector = wv_model.wv[emotion_word]
                ewv += [norm_eweights[eind] * x for x in emotion_word_vector]
        
        # Overlaying the emotion vector with the word vector of the original word.
        emotion_aware_wv[word] = wv_model.wv[word] + ewv

# %%
emotion_aware_wv["great"]
# Out:
# array([ 0.2176701 ,  0.62414142,  0.30286305, -0.58419892,  0.83006238,
#        -0.76335966,  0.18487118,  2.21727284,  0.90564702,  0.53596918,
#         1.35456467, -0.73633766, -0.89404412,  1.32236125, -1.07383049,
#        -1.78690213,  0.27815304,  0.45496689,  0.34918614,  1.86030398,
#         0.2945681 , -0.31027123,  0.41718246, -1.0158881 ,  0.08389386,
#        -0.27827246, -0.88661807, -0.15258321,  0.59904536,  0.0296327 ,
#        -0.9028317 , -1.4707096 , -0.27506155, -0.56707137,  0.17164829,
#        -0.42496213,  0.23103879,  0.66374223, -1.38055027,  0.07703854,
#        -0.38584159, -0.24675348, -0.32854959,  1.38792951, -0.5835358 ,
#        -0.22781488,  1.40032482, -0.1776328 ,  0.17774465, -0.40224682,
#        -0.78711729,  0.3154596 , -0.19536816, -0.38088837,  1.83634757,
#         0.33264691, -0.31929214, -0.11997473, -0.03657924, -0.54895998,
#        -0.15853285, -0.33809169, -0.5996392 ,  0.24255532, -1.55606733,
#         0.2070467 ,  1.51430529,  1.09043041, -0.03458081, -1.42545271,
#        -0.56288128, -0.49472595, -0.15101532,  1.08793109, -0.47360703,
#         0.02024612, -0.06282146,  0.72100439, -2.01024193, -0.01333358,
#         0.19466697,  1.16055596,  1.48359191,  0.6678799 ,  0.27850521,
#         0.11415101, -0.55612495, -1.61927471, -1.26715359,  0.01597876,
#         0.54357346, -0.15239147,  0.20832354,  0.24848136, -0.24795316,
#         0.97119921, -0.48961175,  0.74610948, -0.35893405,  0.70260911,
#        -0.50937652, -0.49980656, -0.98455069,  0.51859563,  1.4693733 ,
#         0.21560849,  0.09029511, -0.19000393,  0.59357438, -0.16639221,
#        -1.19461636,  0.57039958, -0.85805377,  0.70797943, -0.1488472 ,
#         1.01958445, -0.35872187,  0.31332749,  0.74271846,  0.12286989,
#         0.33178163,  0.3415168 ,  0.14470047,  0.55084004,  1.64097359,
#         0.25536279,  1.47930903,  0.49513775, -2.01647484,  0.9344106 ,
#        -0.14606223,  1.21435956,  0.99852656, -0.86296222,  0.61775856,
#        -0.07674598, -0.59389967, -0.67610701, -0.26926753, -0.52576332,
#        -0.32524304,  0.8266186 , -0.35137147,  0.86772471,  0.17993113,
#         0.12308394,  0.33471587, -0.42743729, -0.08147222,  0.01865029,
#         0.81727731, -0.94615596,  1.49786708,  0.78175475,  0.90103446,
#        -0.02837278, -0.09766304,  0.43569558, -0.30935168,  0.27973327,
#         0.5262544 ,  0.10911081, -1.43476812,  0.65825084, -0.05615988,
#        -0.55543652,  0.067077  ,  1.0933093 ,  1.76832391,  0.41035675,
#         0.89289411,  0.66229153,  0.2579267 , -0.45837957, -0.33945018,
#        -0.94836973, -0.60042486, -0.48366123,  0.80819475, -0.70564155,
#        -0.13790399, -0.11702049,  0.19301592, -0.32656102, -0.33377926,
#        -1.01533977, -0.8005173 ,  0.25154189, -1.1560607 , -0.23022297,
#         0.45948143,  0.29136455,  0.41783832,  0.89449228,  2.805627  ,
#        -0.97651063,  1.50889818,  0.15758593, -1.02359032,  0.28470869,
#        -1.08727162, -0.8311131 , -1.52076609, -0.40728993,  0.13102542,
#         0.09257808, -1.01246393,  0.34068789, -0.14686187, -0.25419563,
#         1.29427844, -0.3439117 ,  0.51863496, -0.38850632,  0.59351444,
#         0.55111918, -1.33252051, -0.4298637 ,  0.78974936, -0.68362331,
#        -0.01616718,  0.01288243, -0.72288515, -0.22659893,  1.86162442,
#        -0.19866711,  0.64761897, -0.8895678 , -0.31032387, -0.83960303,
#         0.53856526, -0.45217987, -0.13032476, -0.2512706 ,  0.26914832,
#         1.10186204, -0.27022952,  0.67736086,  0.96001047, -0.58420991,
#         0.85040434,  0.54934114,  0.48438805,  0.0616801 ,  0.61910029,
#        -0.1104052 , -1.58662549,  1.49226127, -0.85977946,  0.28156396,
#        -0.08171876,  0.24331212, -0.94664954, -0.72732065, -1.28088661,
#         0.49015079,  0.78595379,  1.28624919, -0.39884938,  0.26190895,
#         0.37127326,  0.25797253,  1.05383079,  0.46249783, -0.49316072,
#         0.29249852, -0.42342925, -0.80005279,  0.72495415, -0.61501464,
#         0.76457845,  0.83213871,  0.92448014, -0.76012024,  0.30418818,
#         0.49247932,  0.78933965, -0.19504491,  0.25618102, -1.22632177,
#        -0.36356102, -0.27036372,  0.821553  ,  0.19615704, -1.56080381,
#        -0.10297785,  0.97031334,  0.48963353,  0.38253719, -0.52978663,
#         0.26274987,  0.08989052,  0.24211555,  1.34187717, -1.257652  ,
#         1.06259597,  0.60900385,  0.53601764,  0.29516668, -0.82646666])

# %%
# Saving the vocab and Emotion Aware Word Embeddings in an external file.
with open("../output/vocab.csv", "w") as vocabfile:
    for ind, word in enumerate(vocab):
        vocabfile.write("\t".join([str(ind), word]))
        vocabfile.write("\n")

with open("../output/emotionAwareEmbeddings.pkl", "wb") as ewvfile:
    pickle.dump(emotion_aware_wv, file=ewvfile)

# %%
### Demonstrating retrieving the vocab and emotion-aware wv.

with open("../output/emotionAwareEmbeddings.pkl", "rb") as ewvfile:
    emotion_aware_wv = pickle.load(ewvfile)
emotion_aware_wv["great"]
# Out:
# array([ 0.2176701 ,  0.62414142,  0.30286305, -0.58419892,  0.83006238,
#        -0.76335966,  0.18487118,  2.21727284,  0.90564702,  0.53596918,
#         1.35456467, -0.73633766, -0.89404412,  1.32236125, -1.07383049,
#        -1.78690213,  0.27815304,  0.45496689,  0.34918614,  1.86030398,
#         0.2945681 , -0.31027123,  0.41718246, -1.0158881 ,  0.08389386,
#        -0.27827246, -0.88661807, -0.15258321,  0.59904536,  0.0296327 ,
#        -0.9028317 , -1.4707096 , -0.27506155, -0.56707137,  0.17164829,
#        -0.42496213,  0.23103879,  0.66374223, -1.38055027,  0.07703854,
#        -0.38584159, -0.24675348, -0.32854959,  1.38792951, -0.5835358 ,
#        -0.22781488,  1.40032482, -0.1776328 ,  0.17774465, -0.40224682,
#        -0.78711729,  0.3154596 , -0.19536816, -0.38088837,  1.83634757,
#         0.33264691, -0.31929214, -0.11997473, -0.03657924, -0.54895998,
#        -0.15853285, -0.33809169, -0.5996392 ,  0.24255532, -1.55606733,
#         0.2070467 ,  1.51430529,  1.09043041, -0.03458081, -1.42545271,
#        -0.56288128, -0.49472595, -0.15101532,  1.08793109, -0.47360703,
#         0.02024612, -0.06282146,  0.72100439, -2.01024193, -0.01333358,
#         0.19466697,  1.16055596,  1.48359191,  0.6678799 ,  0.27850521,
#         0.11415101, -0.55612495, -1.61927471, -1.26715359,  0.01597876,
#         0.54357346, -0.15239147,  0.20832354,  0.24848136, -0.24795316,
#         0.97119921, -0.48961175,  0.74610948, -0.35893405,  0.70260911,
#        -0.50937652, -0.49980656, -0.98455069,  0.51859563,  1.4693733 ,
#         0.21560849,  0.09029511, -0.19000393,  0.59357438, -0.16639221,
#        -1.19461636,  0.57039958, -0.85805377,  0.70797943, -0.1488472 ,
#         1.01958445, -0.35872187,  0.31332749,  0.74271846,  0.12286989,
#         0.33178163,  0.3415168 ,  0.14470047,  0.55084004,  1.64097359,
#         0.25536279,  1.47930903,  0.49513775, -2.01647484,  0.9344106 ,
#        -0.14606223,  1.21435956,  0.99852656, -0.86296222,  0.61775856,
#        -0.07674598, -0.59389967, -0.67610701, -0.26926753, -0.52576332,
#        -0.32524304,  0.8266186 , -0.35137147,  0.86772471,  0.17993113,
#         0.12308394,  0.33471587, -0.42743729, -0.08147222,  0.01865029,
#         0.81727731, -0.94615596,  1.49786708,  0.78175475,  0.90103446,
#        -0.02837278, -0.09766304,  0.43569558, -0.30935168,  0.27973327,
#         0.5262544 ,  0.10911081, -1.43476812,  0.65825084, -0.05615988,
#        -0.55543652,  0.067077  ,  1.0933093 ,  1.76832391,  0.41035675,
#         0.89289411,  0.66229153,  0.2579267 , -0.45837957, -0.33945018,
#        -0.94836973, -0.60042486, -0.48366123,  0.80819475, -0.70564155,
#        -0.13790399, -0.11702049,  0.19301592, -0.32656102, -0.33377926,
#        -1.01533977, -0.8005173 ,  0.25154189, -1.1560607 , -0.23022297,
#         0.45948143,  0.29136455,  0.41783832,  0.89449228,  2.805627  ,
#        -0.97651063,  1.50889818,  0.15758593, -1.02359032,  0.28470869,
#        -1.08727162, -0.8311131 , -1.52076609, -0.40728993,  0.13102542,
#         0.09257808, -1.01246393,  0.34068789, -0.14686187, -0.25419563,
#         1.29427844, -0.3439117 ,  0.51863496, -0.38850632,  0.59351444,
#         0.55111918, -1.33252051, -0.4298637 ,  0.78974936, -0.68362331,
#        -0.01616718,  0.01288243, -0.72288515, -0.22659893,  1.86162442,
#        -0.19866711,  0.64761897, -0.8895678 , -0.31032387, -0.83960303,
#         0.53856526, -0.45217987, -0.13032476, -0.2512706 ,  0.26914832,
#         1.10186204, -0.27022952,  0.67736086,  0.96001047, -0.58420991,
#         0.85040434,  0.54934114,  0.48438805,  0.0616801 ,  0.61910029,
#        -0.1104052 , -1.58662549,  1.49226127, -0.85977946,  0.28156396,
#        -0.08171876,  0.24331212, -0.94664954, -0.72732065, -1.28088661,
#         0.49015079,  0.78595379,  1.28624919, -0.39884938,  0.26190895,
#         0.37127326,  0.25797253,  1.05383079,  0.46249783, -0.49316072,
#         0.29249852, -0.42342925, -0.80005279,  0.72495415, -0.61501464,
#         0.76457845,  0.83213871,  0.92448014, -0.76012024,  0.30418818,
#         0.49247932,  0.78933965, -0.19504491,  0.25618102, -1.22632177,
#        -0.36356102, -0.27036372,  0.821553  ,  0.19615704, -1.56080381,
#        -0.10297785,  0.97031334,  0.48963353,  0.38253719, -0.52978663,
#         0.26274987,  0.08989052,  0.24211555,  1.34187717, -1.257652  ,
#         1.06259597,  0.60900385,  0.53601764,  0.29516668, -0.82646666])
